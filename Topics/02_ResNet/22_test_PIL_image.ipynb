# %%
from PIL import Image

# Ein Bild laden
img = Image.open("Hydrangeas.jpg")
img = Image.open("Testbild_28_02_2026.png")
#Testbild_28_02_2026.png

# Format-Details anzeigen
print(f"Dateiformat: {img.format}") # z.B. 'JPEG'
print(f"Größe: {img.size}")         # z.B. (800, 600)
print(f"Farbmodus: {img.mode}")     # z.B. 'RGB'
# Out:
# Dateiformat: PNG
# Größe: (480, 323)
# Farbmodus: RGBA
